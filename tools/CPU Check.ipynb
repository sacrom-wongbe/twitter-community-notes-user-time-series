# %% [markdown]
# # CPU Check

# %%
import os, psutil

print("🧠 Logical CPU cores available:", psutil.cpu_count(logical=True))
print("💪 Physical CPU cores:", psutil.cpu_count(logical=False))
print("💾 Total memory (GB):", round(psutil.virtual_memory().total / 1e9, 2))
print("🏷️ Environment:", os.uname())
# Out:
# 🧠 Logical CPU cores available: 16
# 💪 Physical CPU cores: 8
# 💾 Total memory (GB): 135.08
# 🏷️ Environment: posix.uname_result(sysname='Linux', nodename='jupyter-wongbe', release='6.6.97+', version='#1 SMP PREEMPT_DYNAMIC Sat Sep  6 09:47:08 UTC 2025', machine='x86_64')
